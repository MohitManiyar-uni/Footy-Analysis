# %%
import sys
print(sys.executable)
# Out:
# d:\New folder\.venv\Scripts\python.exe

# %%
import sys
import subprocess

subprocess.check_call([
    sys.executable,
    "-m",
    "pip",
    "install",
    "pandas",
    "numpy",
    "scikit-learn",
    "xgboost",
    "requests",
    "beautifulsoup4",
    "jupyter",
    "matplotlib",
    "seaborn",
    "soccerdata"
])
# Out:
# 0

# %%
import soccerdata as sd
# Out:
# [09/09/26 21:29:05] INFO     No custom team name replacements found. You can configure these in       _config.py:91
#                              C:\Users\shubh\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    _config.py:189
#                              C:\Users\shubh\soccerdata\config\league_dict.json.

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons=["2022-23", "2023-24", "2024-25", "2025-26"])
